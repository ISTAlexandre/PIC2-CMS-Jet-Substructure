# %%
import ROOT
import numpy as np

file = ROOT.TFile.Open("../root_ML/merged_ML-pb80.root")
tree = file.Get("jetTree")

n_events = tree.GetEntries()
print(f"Number of events: {n_events}")
# Out:
# Number of events: 25228

# %%
coords = []
hist_channel2_dpsi12_1 = ROOT.TH1F("hist_channel2_dpsi12_1", "dpsi12 distribution channel2 = 1", 100, 0, np.pi)
hist_channel2_dpsi12_1.GetXaxis().SetTitle("dpsi12")
hist_channel2_dpsi12_1.GetYaxis().SetTitle("Counts")

hist_jet_pt = ROOT.TH1F("hist_jet_pt", "Jet pT distribution", 100, 0, 2000)

for n_entry in range(n_events):
    tree.GetEntry(n_entry)
    n_jets = len(tree.jet_pt)

    for jet_i in range(n_jets):

        channel2 = tree.lund_secondary_idx_sd[jet_i]
        channel1 = tree.lund_primary_idx_sd[jet_i]
        max_kt_index1 = int(tree.lund_max_kt_sd[jet_i])
        max_kt_index2 = int(tree.lund_max_kt_secondary_sd[jet_i])
        dpsi12 = tree.lund_psi12_sd[jet_i]

        if channel2 == -1 or max_kt_index1 < 0 or max_kt_index2 < 0 or channel1 == -1:
            continue

        coords.append((channel1, channel2))

        if channel2 == 1:
            hist_channel2_dpsi12_1.Fill(dpsi12)

        jet_pt = tree.jet_pt[jet_i]
        hist_jet_pt.Fill(jet_pt)

# %%
total_coords = len(coords)
for i in range(5):
    for j in range(5):
        count = sum(1 for c in coords if c == (i, j))
        print(f"Channel 1: {i}, Channel 2: {j}, Count: {count}, Percentage: {count/total_coords:.2%};")
# Out:
# Channel 1: 0, Channel 2: 0, Count: 14479, Percentage: 57.61%;
# Channel 1: 0, Channel 2: 1, Count: 3, Percentage: 0.01%;
# Channel 1: 0, Channel 2: 2, Count: 11, Percentage: 0.04%;
# Channel 1: 0, Channel 2: 3, Count: 15, Percentage: 0.06%;
# Channel 1: 0, Channel 2: 4, Count: 2, Percentage: 0.01%;
# Channel 1: 1, Channel 2: 0, Count: 551, Percentage: 2.19%;
# Channel 1: 1, Channel 2: 1, Count: 1, Percentage: 0.00%;
# Channel 1: 1, Channel 2: 2, Count: 82, Percentage: 0.33%;
# Channel 1: 1, Channel 2: 3, Count: 1, Percentage: 0.00%;
# Channel 1: 1, Channel 2: 4, Count: 7, Percentage: 0.03%;
# Channel 1: 2, Channel 2: 0, Count: 3551, Percentage: 14.13%;
# Channel 1: 2, Channel 2: 1, Count: 69, Percentage: 0.27%;
# Channel 1: 2, Channel 2: 2, Count: 200, Percentage: 0.80%;
# Channel 1: 2, Channel 2: 3, Count: 387, Percentage: 1.54%;
# Channel 1: 2, Channel 2: 4, Count: 15, Percentage: 0.06%;
# Channel 1: 3, Channel 2: 0, Count: 2846, Percentage: 11.32%;
# Channel 1: 3, Channel 2: 1, Count: 59, Percentage: 0.23%;
# Channel 1: 3, Channel 2: 2, Count: 28, Percentage: 0.11%;
# Channel 1: 3, Channel 2: 3, Count: 332, Percentage: 1.32%;
# Channel 1: 3, Channel 2: 4, Count: 2, Percentage: 0.01%;
# Channel 1: 4, Channel 2: 0, Count: 1971, Percentage: 7.84%;
# Channel 1: 4, Channel 2: 1, Count: 12, Percentage: 0.05%;
# Channel 1: 4, Channel 2: 2, Count: 246, Percentage: 0.98%;
# Channel 1: 4, Channel 2: 3, Count: 116, Percentage: 0.46%;
# Channel 1: 4, Channel 2: 4, Count: 145, Percentage: 0.58%;

# %%
canvas = ROOT.TCanvas("canvas", "dpsi12 distribution channel2 = 1", 800, 600)
hist_channel2_dpsi12_1.SetLineColor(ROOT.kBlue)
hist_channel2_dpsi12_1.Draw()
canvas.Draw()
canvas.SaveAs("../imgs/frame.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file ../imgs/frame.png has been created
# <div id="root_plot_1783503523832" style="width: 800px; height: 600px; position: relative">
# </div>
#
# </div>
# <script>
#    function process_root_plot_1783503523832() {
#       function execCode(Core) {
#          Core.settings.HandleKeys = false;
#
# Core.unzipJSON(21959,'...').then(json => {
#    const obj = Core.parse(json);
#    Core.draw('root_plot_1783503523832', obj, '');
# });
#
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.11.0/', 'https://jsroot.gsi.de/7.11.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          execCode(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  execCode);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => execCode(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1783503523832();
# </script>

# %%
canvas_jet_pt = ROOT.TCanvas("canvas_jet_pt", "Jet pT distribution", 800, 600)
hist_jet_pt.GetXaxis().SetRangeUser(700, 2000)
hist_jet_pt.SetLineColor(ROOT.kRed)
hist_jet_pt.Draw()
canvas_jet_pt.Draw()
canvas_jet_pt.SaveAs("../imgs/jet_pt_distribution.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas_jet_pt
# Info in <TCanvas::Print>: png file ../imgs/jet_pt_distribution.png has been created
# <div id="root_plot_1783503524006" style="width: 800px; height: 600px; position: relative">
# </div>
#
# </div>
# <script>
#    function process_root_plot_1783503524006() {
#       function execCode(Core) {
#          Core.settings.HandleKeys = false;
#
# Core.unzipJSON(21750,'...').then(json => {
#    const obj = Core.parse(json);
#    Core.draw('root_plot_1783503524006', obj, '');
# });
#
#       }
#       const servers = ['/static/', 'https://root.cern/js/7.11.0/', 'https://jsroot.gsi.de/7.11.0/'],
#             path = 'build/jsroot';
#       if (typeof JSROOT !== 'undefined')
#          execCode(JSROOT);
#       else if (typeof requirejs !== 'undefined') {
#          servers.forEach((s,i) => { servers[i] = s + path; });
#          requirejs.config({ paths: { 'jsroot' : servers } })(['jsroot'],  execCode);
#       } else {
#          const config = document.getElementById('jupyter-config-data');
#          if (config)
#             servers[0] = (JSON.parse(config.innerHTML || '{}')?.baseUrl || '/') + 'static/';
#          else
#             servers.shift();
#          function loadJsroot() {
#             return !servers.length ? 0 : import(servers.shift() + path + '.js').catch(loadJsroot).then(() => execCode(JSROOT));
#          }
#          loadJsroot();
#       }
#    }
#    process_root_plot_1783503524006();
# </script>
