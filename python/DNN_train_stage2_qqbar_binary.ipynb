# %% [markdown]
# # Stage 2 (binary): qqbar vs rest (qg + gg)
#
# Dedicated binary classifier to obtain a **high-purity g→qq̄ sample**.
#
# Trained only on **matched** jets (channel2 ∈ {1,2,3}).
# Target: qqbar (channel2==1) = 1 (signal), qg+gg (channel2∈{2,3}) = 0 (background).
#
# Improvements over the 3-class model:
# - `dpsi12` is **excluded from features** (it is the observable measured later — training on it would bias the measurement). It is kept only for post-hoc validation.
# - log transforms on skewed variables
# - engineered pairwise subjet features
# - **focal loss** + balanced class weights for the ~1:7 imbalance
# - monitor val PR-AUC (right metric for imbalanced signal extraction)

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

from pathlib import Path
import json
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from joblib import dump, load
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    accuracy_score,
    average_precision_score,
    balanced_accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
    precision_recall_curve,
    roc_auc_score,
    roc_curve,
    auc,
)
from sklearn.model_selection import GroupShuffleSplit, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight

try:
    import tensorflow as tf
    from tensorflow import keras
    from tensorflow.keras import layers
except ModuleNotFoundError as exc:
    raise ModuleNotFoundError(
        "TensorFlow is required for this notebook. Install it with: pip install tensorflow"
    ) from exc

warnings.filterwarnings("ignore", category=FutureWarning)

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)

print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.16.2

# %% [markdown]
# ## 1. Paths

# %%
CSV_PATH = Path("merged_ML_ch2.csv")

fallback_paths = [
    Path("merged_ML_ch2.csv"),
    Path("merged_ML_ch2(1).csv"),
    Path("../csv/merged_ML_ch2.csv"),
    Path("../merged_ML_ch2.csv"),
    Path("/mnt/data/merged_ML_ch2.csv"),
]
if not CSV_PATH.exists():
    for path in fallback_paths:
        if path.exists():
            CSV_PATH = path
            break
if not CSV_PATH.exists():
    raise FileNotFoundError("Could not find merged_ML.csv. Set CSV_PATH manually.")

MODEL_DIR  = Path("models_stage2_qqbar_binary")
OUTPUT_DIR = Path("outputs_stage2_qqbar_binary")
MODEL_DIR.mkdir(exist_ok=True)
OUTPUT_DIR.mkdir(exist_ok=True)

print("Using CSV:", CSV_PATH.resolve())
# Out:
# Using CSV: /Users/alexmendonca/Desktop/pic2/csv/merged_ML_ch2.csv

# %% [markdown]
# ## 2. Load + engineer features (dpsi12 KEPT as a feature)

# %%
def add_engineered_features(df: pd.DataFrame) -> pd.DataFrame:
    """Stable transforms + pairwise subjet combinations.
    dpsi12 is intentionally EXCLUDED from features (it is the measured observable)."""
    df = df.copy()

    # Stabilise long-tailed positive variables
    for col in ["pt_dispersion3", "pt_dispersion4"]:
        if col in df.columns:
            df[col] = np.log1p(df[col].clip(lower=0))
    if "kt2" in df.columns:
        df["kt2"] = np.log1p(df["kt2"].clip(lower=0))

    # z variables
    df["z_sum"]          = df["z1"] + df["z2"]
    df["z_absdiff"]      = np.abs(df["z1"] - df["z2"])
    df["z_min"]          = np.minimum(df["z1"], df["z2"])
    df["z_max"]          = np.maximum(df["z1"], df["z2"])
    df["z_minmax_ratio"] = df["z_min"] / (df["z_max"] + 1e-8)

    # Pairwise subjet observables (order-insensitive combinations)
    paired_bases = [
        ("N_charged3", "N_charged4", "N_charged"),
        ("N_all3",     "N_all4",     "N_all"),
        ("pt_weight3", "pt_weight4", "pt_weight"),
        ("pt_dispersion3", "pt_dispersion4", "pt_dispersion"),
    ]
    for c3, c4, name in paired_bases:
        if c3 not in df.columns or c4 not in df.columns:
            continue
        v3, v4 = df[c3], df[c4]
        vmin, vmax = np.minimum(v3, v4), np.maximum(v3, v4)
        df[f"{name}_sum"]          = v3 + v4
        df[f"{name}_absdiff"]      = np.abs(v3 - v4)
        df[f"{name}_min"]          = vmin
        df[f"{name}_max"]          = vmax
        df[f"{name}_minmax_ratio"] = vmin / (vmax + 1e-8)

    # NOTE: dpsi12 is intentionally NOT engineered into a feature.
    # It is the observable we measure later, so it must stay out of training
    # to avoid biasing the measurement (sculpting). It is dropped in the
    # feature-selection step below and used only for post-hoc validation.

    return df


df_raw = pd.read_csv(CSV_PATH)
print("Raw shape:", df_raw.shape)

df = add_engineered_features(df_raw)

ORIGINAL_TARGET = "channel2"
df = df.dropna(subset=[ORIGINAL_TARGET]).copy()
df[ORIGINAL_TARGET] = df[ORIGINAL_TARGET].astype(int)

print("Original channel2 counts:")
print(df[ORIGINAL_TARGET].value_counts().sort_index())
# Out:
# Raw shape: (29874986, 18)
# Original channel2 counts:
# channel2
# 0    22689428
# 1      896936
# 2     1736862
# 3     4298461
# 4      253299
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Build binary target: qqbar vs rest
#
# Keep only matched jets (channel2 ∈ {1,2,3}). Signal = qqbar (1), background = qg+gg (0).

# %%
KEEP = [1, 2, 3]
df = df[df[ORIGINAL_TARGET].isin(KEEP)].copy()

TARGET = "is_qqbar"
df[TARGET] = (df[ORIGINAL_TARGET] == 1).astype(np.int64)   # qqbar=1, qg+gg=0

n_sig = int((df[TARGET] == 1).sum())
n_bkg = int((df[TARGET] == 0).sum())
print(f"Signal (qqbar)      : {n_sig:,}")
print(f"Background (qg+gg)  : {n_bkg:,}")
print(f"Signal fraction     : {n_sig/(n_sig+n_bkg):.4f}")
print(f"Imbalance ratio     : 1 : {n_bkg/n_sig:.1f}")

# Columns never used as features (identifiers, raw target, and the observable).
# dpsi12 is the quantity we measure later, so it is EXCLUDED from features to
# keep the downstream <cos dpsi> measurement unbiased.
DROP_COLS = ["Event", "Jet", "Jet_pt", ORIGINAL_TARGET, TARGET, "dpsi12","tau_time"]
feature_columns = [c for c in df.columns if c not in DROP_COLS]

print(f"\nN features: {len(feature_columns)}")
print("Features:", feature_columns)
# Out:
# Signal (qqbar)      : 896,936
# Background (qg+gg)  : 6,035,323
# Signal fraction     : 0.1294
# Imbalance ratio     : 1 : 6.7
#
# N features: 37
# Features: ['z1', 'z2', 'deltaR34', 'kt2', 'N_charged3', 'N_charged4', 'N_all3', 'N_all4', 'pt_weight3', 'pt_weight4', 'pt_dispersion3', 'pt_dispersion4', 'z_sum', 'z_absdiff', 'z_min', 'z_max', 'z_minmax_ratio', 'N_charged_sum', 'N_charged_absdiff', 'N_charged_min', 'N_charged_max', 'N_charged_minmax_ratio', 'N_all_sum', 'N_all_absdiff', 'N_all_min', 'N_all_max', 'N_all_minmax_ratio', 'pt_weight_sum', 'pt_weight_absdiff', 'pt_weight_min', 'pt_weight_max', 'pt_weight_minmax_ratio', 'pt_dispersion_sum', 'pt_dispersion_absdiff', 'pt_dispersion_min', 'pt_dispersion_max', 'pt_dispersion_minmax_ratio']

# %% [markdown]
# ## 4. Event-grouped train/val/test split (no event leakage across splits)

# %%
X = df[feature_columns]
y = df[TARGET].to_numpy()

if "Event" in df.columns:
    groups = df["Event"].to_numpy()
    gss1 = GroupShuffleSplit(n_splits=1, test_size=0.33, random_state=RANDOM_STATE)
    trainval_idx, test_idx = next(gss1.split(X, y, groups=groups))

    X_trainval, X_test = X.iloc[trainval_idx], X.iloc[test_idx]
    y_trainval, y_test = y[trainval_idx], y[test_idx]
    g_trainval = groups[trainval_idx]

    gss2 = GroupShuffleSplit(n_splits=1, test_size=0.5, random_state=RANDOM_STATE+1)
    tr_idx, val_idx = next(gss2.split(X_trainval, y_trainval, groups=g_trainval))
    X_train, X_val = X_trainval.iloc[tr_idx], X_trainval.iloc[val_idx]
    y_train, y_val = y_trainval[tr_idx], y_trainval[val_idx]
else:
    X_train, X_tmp, y_train, y_tmp = train_test_split(
        X, y, test_size=0.30, random_state=RANDOM_STATE, stratify=y)
    X_val, X_test, y_val, y_test = train_test_split(
        X_tmp, y_tmp, test_size=0.5, random_state=RANDOM_STATE, stratify=y_tmp)

print("Train:", X_train.shape, " Val:", X_val.shape, " Test:", X_test.shape)
for name, yy in [("Train", y_train), ("Val", y_val), ("Test", y_test)]:
    print(f"  {name} signal fraction: {yy.mean():.4f}")
# Out:
# Train: (2321980, 37)  Val: (2322605, 37)  Test: (2287674, 37)
#   Train signal fraction: 0.1294
#   Val signal fraction: 0.1294
#   Test signal fraction: 0.1294

# %% [markdown]
# ## 5. Impute + scale (fit on train only)

# %%
imputer = SimpleImputer(strategy="median")
scaler  = StandardScaler()

X_train_pp = scaler.fit_transform(imputer.fit_transform(X_train)).astype("float32")
X_val_pp   = scaler.transform(imputer.transform(X_val)).astype("float32")
X_test_pp  = scaler.transform(imputer.transform(X_test)).astype("float32")

dump({"imputer": imputer, "scaler": scaler, "features": feature_columns},
     MODEL_DIR / "qqbar_binary_preprocessor.joblib")
print("Saved preprocessor. Shapes:", X_train_pp.shape, X_val_pp.shape, X_test_pp.shape)
# Out:
# Saved preprocessor. Shapes: (2321980, 37) (2322605, 37) (2287674, 37)

# %% [markdown]
# ## 6. Class weights

# %%
raw_w = compute_class_weight("balanced", classes=np.array([0,1]), y=y_train)
class_weight_map = {0: float(raw_w[0]), 1: float(raw_w[1])}
print("Balanced class weights:", class_weight_map)
# Out:
# Balanced class weights: {0: 0.5742923554153366, 1: 3.865083777494432}

# %% [markdown]
# ## 7. Focal loss
#
# Focal loss down-weights easy background and focuses learning on the rare qqbar
# signal. Combined with class weights via the alpha term.

# %%
def binary_focal_loss(gamma=2.0, alpha=0.5):
    """Numerically stable binary focal loss."""
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)
        # p_t = prob of the true class
        p_t = y_true * y_pred + (1 - y_true) * (1 - y_pred)
        alpha_t = y_true * alpha + (1 - y_true) * (1 - alpha)
        fl = -alpha_t * tf.pow(1.0 - p_t, gamma) * tf.math.log(p_t)
        return tf.reduce_mean(fl)
    return loss

# %% [markdown]
# ## 8. Validation-metrics callback (PR-AUC, ROC-AUC, F1)

# %%
class ValMetrics(keras.callbacks.Callback):
    def __init__(self, X_val, y_val):
        super().__init__()
        self.X_val = X_val
        self.y_val = y_val

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        p = self.model.predict(self.X_val, verbose=0).ravel()
        pred = (p >= 0.5).astype(int)
        logs["val_pr_auc"]  = average_precision_score(self.y_val, p)
        logs["val_roc_auc"] = roc_auc_score(self.y_val, p)
        logs["val_f1_sig"]  = f1_score(self.y_val, pred, pos_label=1)
        print(f"  — val_pr_auc={logs['val_pr_auc']:.4f}"
              f"  val_roc_auc={logs['val_roc_auc']:.4f}"
              f"  val_f1_sig={logs['val_f1_sig']:.4f}")

# %% [markdown]
# ## 9. Model

# %%
def build_qqbar_binary_dnn(input_dim):
    model = keras.Sequential([
        layers.Input(shape=(input_dim,), name="features"),

        layers.Dense(256, activation="relu",
                     kernel_regularizer=keras.regularizers.l2(1e-5), name="dense_1"),
        layers.BatchNormalization(name="bn_1"),
        layers.Dropout(0.20, name="dropout_1"),

        layers.Dense(128, activation="relu",
                     kernel_regularizer=keras.regularizers.l2(1e-5), name="dense_2"),
        layers.BatchNormalization(name="bn_2"),
        layers.Dropout(0.20, name="dropout_2"),

        layers.Dense(64, activation="relu",
                     kernel_regularizer=keras.regularizers.l2(1e-5), name="dense_3"),
        layers.BatchNormalization(name="bn_3"),
        layers.Dropout(0.10, name="dropout_3"),

        layers.Dense(1, activation="sigmoid", name="qqbar_probability"),
    ], name="lund_stage2_qqbar_binary_dnn")

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss=binary_focal_loss(gamma=2.0, alpha=0.5),
        metrics=[keras.metrics.AUC(name="auc_roc"),
                 keras.metrics.AUC(name="auc_pr", curve="PR")],
    )
    return model

model = build_qqbar_binary_dnn(X_train_pp.shape[1])
model.summary()
# Out:
# Model: "lund_stage2_qqbar_binary_dnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 256)            │         9,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_1 (BatchNormalization)       │ (None, 256)            │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_2 (BatchNormalization)       │ (None, 128)            │           512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_3 (BatchNormalization)       │ (None, 64)             │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ qqbar_probability (Dense)       │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 52,737 (206.00 KB)
#  Trainable params: 51,841 (202.50 KB)
#  Non-trainable params: 896 (3.50 KB)

# %% [markdown]
# ## 10. Train

# %%
EPOCHS = 300
BATCH_SIZE = 1024
MONITOR = "val_pr_auc"

val_cb = ValMetrics(X_val_pp, y_val)
ckpt = keras.callbacks.ModelCheckpoint(
    str(MODEL_DIR / "qqbar_binary_dnn_best.keras"),
    monitor=MONITOR, mode="max", save_best_only=True, verbose=1)
early = keras.callbacks.EarlyStopping(
    monitor=MONITOR, mode="max", patience=15, restore_best_weights=True, verbose=1)
rlr = keras.callbacks.ReduceLROnPlateau(
    monitor=MONITOR, mode="max", factor=0.5, patience=5, min_lr=1e-6, verbose=1)

history = model.fit(
    X_train_pp, y_train,
    validation_data=(X_val_pp, y_val),
    epochs=EPOCHS, batch_size=BATCH_SIZE,
    class_weight=class_weight_map,
    callbacks=[val_cb, ckpt, early, rlr],
    verbose=1,
)
model.save(MODEL_DIR / "qqbar_binary_dnn_final.keras")
print("Best val PR-AUC:", max(history.history["val_pr_auc"]))
print("Best val ROC-AUC:", max(history.history["val_roc_auc"]))
# Out:
# Epoch 1/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_pr: 0.2013 - auc_roc: 0.6394 - loss: 0.0611  — val_pr_auc=0.3052  val_roc_auc=0.7075  val_f1_sig=0.1022
#
# Epoch 1: val_pr_auc improved from None to 0.30517, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 1: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - auc_pr: 0.2315 - auc_roc: 0.6721 - loss: 0.0527 - val_auc_pr: 0.3051 - val_auc_roc: 0.7074 - val_loss: 0.0484 - val_pr_auc: 0.3052 - val_roc_auc: 0.7075 - val_f1_sig: 0.1022 - learning_rate: 0.0010
# Epoch 2/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.2982 - auc_roc: 0.7018 - loss: 0.0484  — val_pr_auc=0.3059  val_roc_auc=0.7077  val_f1_sig=0.0945
#
# Epoch 2: val_pr_auc improved from 0.30517 to 0.30587, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 2: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 69s 30ms/step - auc_pr: 0.2973 - auc_roc: 0.7023 - loss: 0.0479 - val_auc_pr: 0.3058 - val_auc_roc: 0.7076 - val_loss: 0.0471 - val_pr_auc: 0.3059 - val_roc_auc: 0.7077 - val_f1_sig: 0.0945 - learning_rate: 0.0010
# Epoch 3/300
# 2262/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc_pr: 0.3000 - auc_roc: 0.7041 - loss: 0.0474  — val_pr_auc=0.3055  val_roc_auc=0.7069  val_f1_sig=0.0966
#
# Epoch 3: val_pr_auc did not improve from 0.30587
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 61s 26ms/step - auc_pr: 0.2983 - auc_roc: 0.7038 - loss: 0.0472 - val_auc_pr: 0.3053 - val_auc_roc: 0.7068 - val_loss: 0.0469 - val_pr_auc: 0.3055 - val_roc_auc: 0.7069 - val_f1_sig: 0.0966 - learning_rate: 0.0010
# Epoch 4/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc_pr: 0.3003 - auc_roc: 0.7047 - loss: 0.0472  — val_pr_auc=0.3059  val_roc_auc=0.7072  val_f1_sig=0.0815
#
# Epoch 4: val_pr_auc improved from 0.30587 to 0.30588, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 4: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 69s 30ms/step - auc_pr: 0.2990 - auc_roc: 0.7044 - loss: 0.0470 - val_auc_pr: 0.3057 - val_auc_roc: 0.7070 - val_loss: 0.0468 - val_pr_auc: 0.3059 - val_roc_auc: 0.7072 - val_f1_sig: 0.0815 - learning_rate: 0.0010
# Epoch 5/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3005 - auc_roc: 0.7052 - loss: 0.0471  — val_pr_auc=0.3058  val_roc_auc=0.7074  val_f1_sig=0.1056
#
# Epoch 5: val_pr_auc did not improve from 0.30588
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 72s 32ms/step - auc_pr: 0.2991 - auc_roc: 0.7047 - loss: 0.0470 - val_auc_pr: 0.3057 - val_auc_roc: 0.7073 - val_loss: 0.0468 - val_pr_auc: 0.3058 - val_roc_auc: 0.7074 - val_f1_sig: 0.1056 - learning_rate: 0.0010
# Epoch 6/300
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc_pr: 0.3009 - auc_roc: 0.7053 - loss: 0.0471  — val_pr_auc=0.3057  val_roc_auc=0.7075  val_f1_sig=0.0864
#
# Epoch 6: val_pr_auc did not improve from 0.30588
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 63s 28ms/step - auc_pr: 0.2992 - auc_roc: 0.7049 - loss: 0.0470 - val_auc_pr: 0.3056 - val_auc_roc: 0.7074 - val_loss: 0.0468 - val_pr_auc: 0.3057 - val_roc_auc: 0.7075 - val_f1_sig: 0.0864 - learning_rate: 0.0010
# Epoch 7/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_pr: 0.3011 - auc_roc: 0.7054 - loss: 0.0471  — val_pr_auc=0.3059  val_roc_auc=0.7077  val_f1_sig=0.0818
#
# Epoch 7: val_pr_auc did not improve from 0.30588
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 77s 34ms/step - auc_pr: 0.2994 - auc_roc: 0.7051 - loss: 0.0470 - val_auc_pr: 0.3057 - val_auc_roc: 0.7076 - val_loss: 0.0468 - val_pr_auc: 0.3059 - val_roc_auc: 0.7077 - val_f1_sig: 0.0818 - learning_rate: 0.0010
# Epoch 8/300
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_pr: 0.3039 - auc_roc: 0.7075 - loss: 0.0470  — val_pr_auc=0.3091  val_roc_auc=0.7099  val_f1_sig=0.0778
#
# Epoch 8: val_pr_auc improved from 0.30588 to 0.30907, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 8: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 75s 33ms/step - auc_pr: 0.3023 - auc_roc: 0.7071 - loss: 0.0468 - val_auc_pr: 0.3090 - val_auc_roc: 0.7098 - val_loss: 0.0466 - val_pr_auc: 0.3091 - val_roc_auc: 0.7099 - val_f1_sig: 0.0778 - learning_rate: 5.0000e-04
# Epoch 9/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_pr: 0.3042 - auc_roc: 0.7079 - loss: 0.0469  — val_pr_auc=0.3094  val_roc_auc=0.7103  val_f1_sig=0.0822
#
# Epoch 9: val_pr_auc improved from 0.30907 to 0.30937, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 9: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 79s 35ms/step - auc_pr: 0.3025 - auc_roc: 0.7074 - loss: 0.0468 - val_auc_pr: 0.3092 - val_auc_roc: 0.7102 - val_loss: 0.0466 - val_pr_auc: 0.3094 - val_roc_auc: 0.7103 - val_f1_sig: 0.0822 - learning_rate: 5.0000e-04
# Epoch 10/300
# 2264/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc_pr: 0.3044 - auc_roc: 0.7078 - loss: 0.0469  — val_pr_auc=0.3090  val_roc_auc=0.7097  val_f1_sig=0.0838
#
# Epoch 10: val_pr_auc did not improve from 0.30937
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 78s 34ms/step - auc_pr: 0.3031 - auc_roc: 0.7074 - loss: 0.0468 - val_auc_pr: 0.3089 - val_auc_roc: 0.7095 - val_loss: 0.0466 - val_pr_auc: 0.3090 - val_roc_auc: 0.7097 - val_f1_sig: 0.0838 - learning_rate: 5.0000e-04
# Epoch 11/300
# 2264/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc_pr: 0.3045 - auc_roc: 0.7081 - loss: 0.0469  — val_pr_auc=0.3096  val_roc_auc=0.7103  val_f1_sig=0.0865
#
# Epoch 11: val_pr_auc improved from 0.30937 to 0.30962, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 11: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 80s 35ms/step - auc_pr: 0.3030 - auc_roc: 0.7077 - loss: 0.0468 - val_auc_pr: 0.3095 - val_auc_roc: 0.7102 - val_loss: 0.0466 - val_pr_auc: 0.3096 - val_roc_auc: 0.7103 - val_f1_sig: 0.0865 - learning_rate: 5.0000e-04
# Epoch 12/300
# 2264/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_pr: 0.3047 - auc_roc: 0.7081 - loss: 0.0469  — val_pr_auc=0.3096  val_roc_auc=0.7104  val_f1_sig=0.0973
#
# Epoch 12: val_pr_auc did not improve from 0.30962
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 79s 35ms/step - auc_pr: 0.3031 - auc_roc: 0.7077 - loss: 0.0468 - val_auc_pr: 0.3095 - val_auc_roc: 0.7102 - val_loss: 0.0466 - val_pr_auc: 0.3096 - val_roc_auc: 0.7104 - val_f1_sig: 0.0973 - learning_rate: 5.0000e-04
# Epoch 13/300
# 2267/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc_pr: 0.3049 - auc_roc: 0.7083 - loss: 0.0469  — val_pr_auc=0.3095  val_roc_auc=0.7104  val_f1_sig=0.0833
#
# Epoch 13: val_pr_auc did not improve from 0.30962
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 78s 34ms/step - auc_pr: 0.3030 - auc_roc: 0.7077 - loss: 0.0468 - val_auc_pr: 0.3094 - val_auc_roc: 0.7103 - val_loss: 0.0466 - val_pr_auc: 0.3095 - val_roc_auc: 0.7104 - val_f1_sig: 0.0833 - learning_rate: 5.0000e-04
# Epoch 14/300
# 2264/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc_pr: 0.3048 - auc_roc: 0.7083 - loss: 0.0469  — val_pr_auc=0.3097  val_roc_auc=0.7105  val_f1_sig=0.1042
#
# Epoch 14: val_pr_auc improved from 0.30962 to 0.30968, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 14: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 83s 36ms/step - auc_pr: 0.3034 - auc_roc: 0.7078 - loss: 0.0468 - val_auc_pr: 0.3096 - val_auc_roc: 0.7103 - val_loss: 0.0465 - val_pr_auc: 0.3097 - val_roc_auc: 0.7105 - val_f1_sig: 0.1042 - learning_rate: 5.0000e-04
# Epoch 15/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc_pr: 0.3047 - auc_roc: 0.7084 - loss: 0.0469  — val_pr_auc=0.3095  val_roc_auc=0.7102  val_f1_sig=0.0891
#
# Epoch 15: val_pr_auc did not improve from 0.30968
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 82s 36ms/step - auc_pr: 0.3030 - auc_roc: 0.7079 - loss: 0.0468 - val_auc_pr: 0.3093 - val_auc_roc: 0.7101 - val_loss: 0.0466 - val_pr_auc: 0.3095 - val_roc_auc: 0.7102 - val_f1_sig: 0.0891 - learning_rate: 5.0000e-04
# Epoch 16/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc_pr: 0.3049 - auc_roc: 0.7083 - loss: 0.0469  — val_pr_auc=0.3090  val_roc_auc=0.7096  val_f1_sig=0.0768
#
# Epoch 16: val_pr_auc did not improve from 0.30968
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 87s 38ms/step - auc_pr: 0.3031 - auc_roc: 0.7079 - loss: 0.0468 - val_auc_pr: 0.3089 - val_auc_roc: 0.7094 - val_loss: 0.0466 - val_pr_auc: 0.3090 - val_roc_auc: 0.7096 - val_f1_sig: 0.0768 - learning_rate: 5.0000e-04
# Epoch 17/300
# 2262/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc_pr: 0.3066 - auc_roc: 0.7094 - loss: 0.0468  — val_pr_auc=0.3107  val_roc_auc=0.7115  val_f1_sig=0.0862
#
# Epoch 17: val_pr_auc improved from 0.30968 to 0.31070, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 17: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 77s 34ms/step - auc_pr: 0.3053 - auc_roc: 0.7090 - loss: 0.0467 - val_auc_pr: 0.3106 - val_auc_roc: 0.7114 - val_loss: 0.0465 - val_pr_auc: 0.3107 - val_roc_auc: 0.7115 - val_f1_sig: 0.0862 - learning_rate: 2.5000e-04
# Epoch 18/300
# 2264/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3069 - auc_roc: 0.7097 - loss: 0.0468  — val_pr_auc=0.3110  val_roc_auc=0.7116  val_f1_sig=0.1002
#
# Epoch 18: val_pr_auc improved from 0.31070 to 0.31101, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 18: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 87s 38ms/step - auc_pr: 0.3052 - auc_roc: 0.7092 - loss: 0.0467 - val_auc_pr: 0.3109 - val_auc_roc: 0.7115 - val_loss: 0.0465 - val_pr_auc: 0.3110 - val_roc_auc: 0.7116 - val_f1_sig: 0.1002 - learning_rate: 2.5000e-04
# Epoch 19/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_pr: 0.3069 - auc_roc: 0.7098 - loss: 0.0468  — val_pr_auc=0.3110  val_roc_auc=0.7116  val_f1_sig=0.0906
#
# Epoch 19: val_pr_auc did not improve from 0.31101
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 88s 39ms/step - auc_pr: 0.3054 - auc_roc: 0.7094 - loss: 0.0466 - val_auc_pr: 0.3109 - val_auc_roc: 0.7115 - val_loss: 0.0465 - val_pr_auc: 0.3110 - val_roc_auc: 0.7116 - val_f1_sig: 0.0906 - learning_rate: 2.5000e-04
# Epoch 20/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3077 - auc_roc: 0.7099 - loss: 0.0468  — val_pr_auc=0.3110  val_roc_auc=0.7116  val_f1_sig=0.0971
#
# Epoch 20: val_pr_auc did not improve from 0.31101
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 86s 38ms/step - auc_pr: 0.3058 - auc_roc: 0.7094 - loss: 0.0466 - val_auc_pr: 0.3109 - val_auc_roc: 0.7115 - val_loss: 0.0465 - val_pr_auc: 0.3110 - val_roc_auc: 0.7116 - val_f1_sig: 0.0971 - learning_rate: 2.5000e-04
# Epoch 21/300
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3073 - auc_roc: 0.7100 - loss: 0.0468  — val_pr_auc=0.3111  val_roc_auc=0.7118  val_f1_sig=0.0982
#
# Epoch 21: val_pr_auc improved from 0.31101 to 0.31110, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 21: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 97s 43ms/step - auc_pr: 0.3056 - auc_roc: 0.7095 - loss: 0.0466 - val_auc_pr: 0.3110 - val_auc_roc: 0.7117 - val_loss: 0.0465 - val_pr_auc: 0.3111 - val_roc_auc: 0.7118 - val_f1_sig: 0.0982 - learning_rate: 2.5000e-04
# Epoch 22/300
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc_pr: 0.3072 - auc_roc: 0.7100 - loss: 0.0468  — val_pr_auc=0.3111  val_roc_auc=0.7118  val_f1_sig=0.0926
#
# Epoch 22: val_pr_auc did not improve from 0.31110
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 91s 40ms/step - auc_pr: 0.3059 - auc_roc: 0.7096 - loss: 0.0466 - val_auc_pr: 0.3110 - val_auc_roc: 0.7117 - val_loss: 0.0465 - val_pr_auc: 0.3111 - val_roc_auc: 0.7118 - val_f1_sig: 0.0926 - learning_rate: 2.5000e-04
# Epoch 23/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3071 - auc_roc: 0.7099 - loss: 0.0468  — val_pr_auc=0.3111  val_roc_auc=0.7118  val_f1_sig=0.1001
#
# Epoch 23: val_pr_auc did not improve from 0.31110
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 92s 41ms/step - auc_pr: 0.3058 - auc_roc: 0.7095 - loss: 0.0466 - val_auc_pr: 0.3110 - val_auc_roc: 0.7116 - val_loss: 0.0465 - val_pr_auc: 0.3111 - val_roc_auc: 0.7118 - val_f1_sig: 0.1001 - learning_rate: 2.5000e-04
# Epoch 24/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_pr: 0.3087 - auc_roc: 0.7109 - loss: 0.0467  — val_pr_auc=0.3119  val_roc_auc=0.7125  val_f1_sig=0.1039
#
# Epoch 24: val_pr_auc improved from 0.31110 to 0.31188, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 24: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 95s 42ms/step - auc_pr: 0.3071 - auc_roc: 0.7105 - loss: 0.0466 - val_auc_pr: 0.3118 - val_auc_roc: 0.7124 - val_loss: 0.0464 - val_pr_auc: 0.3119 - val_roc_auc: 0.7125 - val_f1_sig: 0.1039 - learning_rate: 1.2500e-04
# Epoch 25/300
# 2264/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3088 - auc_roc: 0.7108 - loss: 0.0467  — val_pr_auc=0.3118  val_roc_auc=0.7125  val_f1_sig=0.1026
#
# Epoch 25: val_pr_auc did not improve from 0.31188
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 91s 40ms/step - auc_pr: 0.3072 - auc_roc: 0.7103 - loss: 0.0466 - val_auc_pr: 0.3117 - val_auc_roc: 0.7124 - val_loss: 0.0464 - val_pr_auc: 0.3118 - val_roc_auc: 0.7125 - val_f1_sig: 0.1026 - learning_rate: 1.2500e-04
# Epoch 26/300
# 2264/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3087 - auc_roc: 0.7108 - loss: 0.0467  — val_pr_auc=0.3119  val_roc_auc=0.7126  val_f1_sig=0.0999
#
# Epoch 26: val_pr_auc improved from 0.31188 to 0.31189, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 26: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 95s 42ms/step - auc_pr: 0.3072 - auc_roc: 0.7104 - loss: 0.0466 - val_auc_pr: 0.3118 - val_auc_roc: 0.7124 - val_loss: 0.0464 - val_pr_auc: 0.3119 - val_roc_auc: 0.7126 - val_f1_sig: 0.0999 - learning_rate: 1.2500e-04
# Epoch 27/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_pr: 0.3088 - auc_roc: 0.7111 - loss: 0.0467  — val_pr_auc=0.3118  val_roc_auc=0.7124  val_f1_sig=0.0963
#
# Epoch 27: val_pr_auc did not improve from 0.31189
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 81s 35ms/step - auc_pr: 0.3074 - auc_roc: 0.7107 - loss: 0.0466 - val_auc_pr: 0.3117 - val_auc_roc: 0.7123 - val_loss: 0.0464 - val_pr_auc: 0.3118 - val_roc_auc: 0.7124 - val_f1_sig: 0.0963 - learning_rate: 1.2500e-04
# Epoch 28/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3091 - auc_roc: 0.7112 - loss: 0.0467  — val_pr_auc=0.3119  val_roc_auc=0.7125  val_f1_sig=0.0957
#
# Epoch 28: val_pr_auc improved from 0.31189 to 0.31189, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 28: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 87s 38ms/step - auc_pr: 0.3076 - auc_roc: 0.7106 - loss: 0.0466 - val_auc_pr: 0.3118 - val_auc_roc: 0.7124 - val_loss: 0.0464 - val_pr_auc: 0.3119 - val_roc_auc: 0.7125 - val_f1_sig: 0.0957 - learning_rate: 1.2500e-04
# Epoch 29/300
# 2263/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc_pr: 0.3092 - auc_roc: 0.7111 - loss: 0.0467  — val_pr_auc=0.3120  val_roc_auc=0.7126  val_f1_sig=0.0992
#
# Epoch 29: val_pr_auc improved from 0.31189 to 0.31195, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 29: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 89s 39ms/step - auc_pr: 0.3076 - auc_roc: 0.7107 - loss: 0.0466 - val_auc_pr: 0.3118 - val_auc_roc: 0.7125 - val_loss: 0.0464 - val_pr_auc: 0.3120 - val_roc_auc: 0.7126 - val_f1_sig: 0.0992 - learning_rate: 1.2500e-04
# Epoch 30/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc_pr: 0.3097 - auc_roc: 0.7117 - loss: 0.0467  — val_pr_auc=0.3123  val_roc_auc=0.7130  val_f1_sig=0.0983
#
# Epoch 30: val_pr_auc improved from 0.31195 to 0.31232, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 30: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 88s 39ms/step - auc_pr: 0.3083 - auc_roc: 0.7112 - loss: 0.0465 - val_auc_pr: 0.3122 - val_auc_roc: 0.7128 - val_loss: 0.0464 - val_pr_auc: 0.3123 - val_roc_auc: 0.7130 - val_f1_sig: 0.0983 - learning_rate: 6.2500e-05
# Epoch 31/300
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3099 - auc_roc: 0.7118 - loss: 0.0466  — val_pr_auc=0.3124  val_roc_auc=0.7129  val_f1_sig=0.1004
#
# Epoch 31: val_pr_auc improved from 0.31232 to 0.31239, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 31: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 92s 40ms/step - auc_pr: 0.3085 - auc_roc: 0.7113 - loss: 0.0465 - val_auc_pr: 0.3122 - val_auc_roc: 0.7128 - val_loss: 0.0464 - val_pr_auc: 0.3124 - val_roc_auc: 0.7129 - val_f1_sig: 0.1004 - learning_rate: 6.2500e-05
# Epoch 32/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_pr: 0.3098 - auc_roc: 0.7116 - loss: 0.0467  — val_pr_auc=0.3124  val_roc_auc=0.7130  val_f1_sig=0.1006
#
# Epoch 32: val_pr_auc improved from 0.31239 to 0.31239, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 32: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 87s 38ms/step - auc_pr: 0.3084 - auc_roc: 0.7112 - loss: 0.0465 - val_auc_pr: 0.3123 - val_auc_roc: 0.7128 - val_loss: 0.0464 - val_pr_auc: 0.3124 - val_roc_auc: 0.7130 - val_f1_sig: 0.1006 - learning_rate: 6.2500e-05
# Epoch 33/300
# 2264/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3102 - auc_roc: 0.7119 - loss: 0.0466  — val_pr_auc=0.3124  val_roc_auc=0.7129  val_f1_sig=0.1102
#
# Epoch 33: val_pr_auc improved from 0.31239 to 0.31241, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 33: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 95s 42ms/step - auc_pr: 0.3086 - auc_roc: 0.7114 - loss: 0.0465 - val_auc_pr: 0.3123 - val_auc_roc: 0.7128 - val_loss: 0.0464 - val_pr_auc: 0.3124 - val_roc_auc: 0.7129 - val_f1_sig: 0.1102 - learning_rate: 6.2500e-05
# Epoch 34/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc_pr: 0.3102 - auc_roc: 0.7120 - loss: 0.0466  — val_pr_auc=0.3123  val_roc_auc=0.7129  val_f1_sig=0.1014
#
# Epoch 34: val_pr_auc did not improve from 0.31241
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 85s 37ms/step - auc_pr: 0.3088 - auc_roc: 0.7114 - loss: 0.0465 - val_auc_pr: 0.3122 - val_auc_roc: 0.7128 - val_loss: 0.0464 - val_pr_auc: 0.3123 - val_roc_auc: 0.7129 - val_f1_sig: 0.1014 - learning_rate: 6.2500e-05
# Epoch 35/300
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3104 - auc_roc: 0.7119 - loss: 0.0466  — val_pr_auc=0.3124  val_roc_auc=0.7129  val_f1_sig=0.1043
#
# Epoch 35: val_pr_auc did not improve from 0.31241
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 86s 38ms/step - auc_pr: 0.3086 - auc_roc: 0.7114 - loss: 0.0465 - val_auc_pr: 0.3123 - val_auc_roc: 0.7128 - val_loss: 0.0464 - val_pr_auc: 0.3124 - val_roc_auc: 0.7129 - val_f1_sig: 0.1043 - learning_rate: 6.2500e-05
# Epoch 36/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3106 - auc_roc: 0.7121 - loss: 0.0466  — val_pr_auc=0.3126  val_roc_auc=0.7131  val_f1_sig=0.1059
#
# Epoch 36: val_pr_auc improved from 0.31241 to 0.31255, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 36: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 90s 40ms/step - auc_pr: 0.3092 - auc_roc: 0.7117 - loss: 0.0465 - val_auc_pr: 0.3125 - val_auc_roc: 0.7130 - val_loss: 0.0464 - val_pr_auc: 0.3126 - val_roc_auc: 0.7131 - val_f1_sig: 0.1059 - learning_rate: 3.1250e-05
# Epoch 37/300
# 2264/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc_pr: 0.3110 - auc_roc: 0.7123 - loss: 0.0466  — val_pr_auc=0.3126  val_roc_auc=0.7131  val_f1_sig=0.1079
#
# Epoch 37: val_pr_auc improved from 0.31255 to 0.31262, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 37: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 86s 38ms/step - auc_pr: 0.3096 - auc_roc: 0.7119 - loss: 0.0465 - val_auc_pr: 0.3125 - val_auc_roc: 0.7130 - val_loss: 0.0464 - val_pr_auc: 0.3126 - val_roc_auc: 0.7131 - val_f1_sig: 0.1079 - learning_rate: 3.1250e-05
# Epoch 38/300
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3109 - auc_roc: 0.7124 - loss: 0.0466  — val_pr_auc=0.3127  val_roc_auc=0.7132  val_f1_sig=0.1033
#
# Epoch 38: val_pr_auc improved from 0.31262 to 0.31266, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 38: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 90s 40ms/step - auc_pr: 0.3095 - auc_roc: 0.7119 - loss: 0.0465 - val_auc_pr: 0.3125 - val_auc_roc: 0.7130 - val_loss: 0.0464 - val_pr_auc: 0.3127 - val_roc_auc: 0.7132 - val_f1_sig: 0.1033 - learning_rate: 3.1250e-05
# Epoch 39/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3111 - auc_roc: 0.7123 - loss: 0.0466  — val_pr_auc=0.3127  val_roc_auc=0.7132  val_f1_sig=0.1078
#
# Epoch 39: val_pr_auc did not improve from 0.31266
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 93s 41ms/step - auc_pr: 0.3096 - auc_roc: 0.7119 - loss: 0.0465 - val_auc_pr: 0.3125 - val_auc_roc: 0.7130 - val_loss: 0.0464 - val_pr_auc: 0.3127 - val_roc_auc: 0.7132 - val_f1_sig: 0.1078 - learning_rate: 3.1250e-05
# Epoch 40/300
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.3111 - auc_roc: 0.7125 - loss: 0.0466  — val_pr_auc=0.3127  val_roc_auc=0.7132  val_f1_sig=0.1030
#
# Epoch 40: val_pr_auc improved from 0.31266 to 0.31274, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 40: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 111s 49ms/step - auc_pr: 0.3096 - auc_roc: 0.7119 - loss: 0.0465 - val_auc_pr: 0.3126 - val_auc_roc: 0.7130 - val_loss: 0.0464 - val_pr_auc: 0.3127 - val_roc_auc: 0.7132 - val_f1_sig: 0.1030 - learning_rate: 3.1250e-05
# Epoch 41/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3114 - auc_roc: 0.7125 - loss: 0.0466  — val_pr_auc=0.3127  val_roc_auc=0.7132  val_f1_sig=0.1038
#
# Epoch 41: val_pr_auc did not improve from 0.31274
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 116s 51ms/step - auc_pr: 0.3096 - auc_roc: 0.7119 - loss: 0.0465 - val_auc_pr: 0.3125 - val_auc_roc: 0.7131 - val_loss: 0.0464 - val_pr_auc: 0.3127 - val_roc_auc: 0.7132 - val_f1_sig: 0.1038 - learning_rate: 3.1250e-05
# Epoch 42/300
# 2267/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc_pr: 0.3109 - auc_roc: 0.7124 - loss: 0.0466  — val_pr_auc=0.3127  val_roc_auc=0.7132  val_f1_sig=0.1068
#
# Epoch 42: val_pr_auc did not improve from 0.31274
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 108s 48ms/step - auc_pr: 0.3095 - auc_roc: 0.7119 - loss: 0.0465 - val_auc_pr: 0.3126 - val_auc_roc: 0.7131 - val_loss: 0.0464 - val_pr_auc: 0.3127 - val_roc_auc: 0.7132 - val_f1_sig: 0.1068 - learning_rate: 3.1250e-05
# Epoch 43/300
# 2267/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc_pr: 0.3111 - auc_roc: 0.7126 - loss: 0.0466  — val_pr_auc=0.3127  val_roc_auc=0.7132  val_f1_sig=0.1058
#
# Epoch 43: val_pr_auc did not improve from 0.31274
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 127s 56ms/step - auc_pr: 0.3096 - auc_roc: 0.7120 - loss: 0.0465 - val_auc_pr: 0.3126 - val_auc_roc: 0.7131 - val_loss: 0.0464 - val_pr_auc: 0.3127 - val_roc_auc: 0.7132 - val_f1_sig: 0.1058 - learning_rate: 3.1250e-05
# Epoch 44/300
# 2267/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3115 - auc_roc: 0.7126 - loss: 0.0466  — val_pr_auc=0.3127  val_roc_auc=0.7133  val_f1_sig=0.1108
#
# Epoch 44: val_pr_auc improved from 0.31274 to 0.31275, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 44: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 101s 44ms/step - auc_pr: 0.3100 - auc_roc: 0.7122 - loss: 0.0465 - val_auc_pr: 0.3127 - val_auc_roc: 0.7131 - val_loss: 0.0463 - val_pr_auc: 0.3127 - val_roc_auc: 0.7133 - val_f1_sig: 0.1108 - learning_rate: 1.5625e-05
# Epoch 45/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3113 - auc_roc: 0.7129 - loss: 0.0466  — val_pr_auc=0.3128  val_roc_auc=0.7133  val_f1_sig=0.1100
#
# Epoch 45: val_pr_auc improved from 0.31275 to 0.31282, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 45: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 93s 41ms/step - auc_pr: 0.3099 - auc_roc: 0.7124 - loss: 0.0465 - val_auc_pr: 0.3127 - val_auc_roc: 0.7132 - val_loss: 0.0463 - val_pr_auc: 0.3128 - val_roc_auc: 0.7133 - val_f1_sig: 0.1100 - learning_rate: 1.5625e-05
# Epoch 46/300
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3113 - auc_roc: 0.7128 - loss: 0.0466  — val_pr_auc=0.3128  val_roc_auc=0.7133  val_f1_sig=0.1104
#
# Epoch 46: val_pr_auc improved from 0.31282 to 0.31283, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 46: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 94s 42ms/step - auc_pr: 0.3100 - auc_roc: 0.7123 - loss: 0.0465 - val_auc_pr: 0.3127 - val_auc_roc: 0.7132 - val_loss: 0.0463 - val_pr_auc: 0.3128 - val_roc_auc: 0.7133 - val_f1_sig: 0.1104 - learning_rate: 1.5625e-05
# Epoch 47/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3113 - auc_roc: 0.7127 - loss: 0.0466  — val_pr_auc=0.3128  val_roc_auc=0.7133  val_f1_sig=0.1089
#
# Epoch 47: val_pr_auc did not improve from 0.31283
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 96s 42ms/step - auc_pr: 0.3100 - auc_roc: 0.7123 - loss: 0.0465 - val_auc_pr: 0.3127 - val_auc_roc: 0.7132 - val_loss: 0.0463 - val_pr_auc: 0.3128 - val_roc_auc: 0.7133 - val_f1_sig: 0.1089 - learning_rate: 1.5625e-05
# Epoch 48/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc_pr: 0.3118 - auc_roc: 0.7129 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7133  val_f1_sig=0.1111
#
# Epoch 48: val_pr_auc improved from 0.31283 to 0.31285, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 48: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 93s 41ms/step - auc_pr: 0.3102 - auc_roc: 0.7123 - loss: 0.0465 - val_auc_pr: 0.3128 - val_auc_roc: 0.7132 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7133 - val_f1_sig: 0.1111 - learning_rate: 1.5625e-05
# Epoch 49/300
# 2264/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc_pr: 0.3115 - auc_roc: 0.7127 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7133  val_f1_sig=0.1110
#
# Epoch 49: val_pr_auc improved from 0.31285 to 0.31286, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 49: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 72s 32ms/step - auc_pr: 0.3100 - auc_roc: 0.7122 - loss: 0.0465 - val_auc_pr: 0.3127 - val_auc_roc: 0.7132 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7133 - val_f1_sig: 0.1110 - learning_rate: 1.5625e-05
# Epoch 50/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_pr: 0.3121 - auc_roc: 0.7130 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7133  val_f1_sig=0.1085
#
# Epoch 50: val_pr_auc improved from 0.31286 to 0.31288, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 50: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 60s 26ms/step - auc_pr: 0.3104 - auc_roc: 0.7125 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7132 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7133 - val_f1_sig: 0.1085 - learning_rate: 1.5625e-05
# Epoch 51/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc_pr: 0.3116 - auc_roc: 0.7127 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1131
#
# Epoch 51: val_pr_auc improved from 0.31288 to 0.31290, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 51: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 78s 34ms/step - auc_pr: 0.3103 - auc_roc: 0.7124 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7132 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1131 - learning_rate: 7.8125e-06
# Epoch 52/300
# 2267/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3123 - auc_roc: 0.7129 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1123
#
# Epoch 52: val_pr_auc did not improve from 0.31290
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 58s 25ms/step - auc_pr: 0.3106 - auc_roc: 0.7124 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7132 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1123 - learning_rate: 7.8125e-06
# Epoch 53/300
# 2267/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3119 - auc_roc: 0.7128 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1118
#
# Epoch 53: val_pr_auc did not improve from 0.31290
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 56s 25ms/step - auc_pr: 0.3102 - auc_roc: 0.7124 - loss: 0.0465 - val_auc_pr: 0.3128 - val_auc_roc: 0.7132 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1118 - learning_rate: 7.8125e-06
# Epoch 54/300
# 2267/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3120 - auc_roc: 0.7129 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1135
#
# Epoch 54: val_pr_auc did not improve from 0.31290
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 56s 25ms/step - auc_pr: 0.3103 - auc_roc: 0.7124 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1135 - learning_rate: 7.8125e-06
# Epoch 55/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3119 - auc_roc: 0.7130 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1129
#
# Epoch 55: val_pr_auc did not improve from 0.31290
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 56s 25ms/step - auc_pr: 0.3103 - auc_roc: 0.7124 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1129 - learning_rate: 7.8125e-06
# Epoch 56/300
# 2264/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3120 - auc_roc: 0.7131 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1144
#
# Epoch 56: val_pr_auc did not improve from 0.31290
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 55s 24ms/step - auc_pr: 0.3103 - auc_roc: 0.7126 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1144 - learning_rate: 3.9063e-06
# Epoch 57/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3120 - auc_roc: 0.7130 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1154
#
# Epoch 57: val_pr_auc did not improve from 0.31290
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 56s 25ms/step - auc_pr: 0.3104 - auc_roc: 0.7124 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1154 - learning_rate: 3.9063e-06
# Epoch 58/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3119 - auc_roc: 0.7129 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1148
#
# Epoch 58: val_pr_auc improved from 0.31290 to 0.31290, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 58: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 57s 25ms/step - auc_pr: 0.3103 - auc_roc: 0.7126 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1148 - learning_rate: 3.9063e-06
# Epoch 59/300
# 2263/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3120 - auc_roc: 0.7128 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1147
#
# Epoch 59: val_pr_auc improved from 0.31290 to 0.31291, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 59: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 56s 25ms/step - auc_pr: 0.3104 - auc_roc: 0.7124 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1147 - learning_rate: 3.9063e-06
# Epoch 60/300
# 2263/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc_pr: 0.3122 - auc_roc: 0.7131 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1150
#
# Epoch 60: val_pr_auc improved from 0.31291 to 0.31293, saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
#
# Epoch 60: finished saving model to models_stage2_qqbar_binary/qqbar_binary_dnn_best.keras
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 55s 24ms/step - auc_pr: 0.3105 - auc_roc: 0.7126 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1150 - learning_rate: 3.9063e-06
# Epoch 61/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3119 - auc_roc: 0.7129 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1157
#
# Epoch 61: val_pr_auc did not improve from 0.31293
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 55s 24ms/step - auc_pr: 0.3104 - auc_roc: 0.7125 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1157 - learning_rate: 3.9063e-06
# Epoch 62/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3119 - auc_roc: 0.7130 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1152
#
# Epoch 62: val_pr_auc did not improve from 0.31293
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 57s 25ms/step - auc_pr: 0.3104 - auc_roc: 0.7125 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1152 - learning_rate: 3.9063e-06
# Epoch 63/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3122 - auc_roc: 0.7133 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1149
#
# Epoch 63: val_pr_auc did not improve from 0.31293
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 62s 27ms/step - auc_pr: 0.3105 - auc_roc: 0.7127 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1149 - learning_rate: 3.9063e-06
# Epoch 64/300
# 2264/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3119 - auc_roc: 0.7132 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1158
#
# Epoch 64: val_pr_auc did not improve from 0.31293
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 60s 26ms/step - auc_pr: 0.3106 - auc_roc: 0.7127 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1158 - learning_rate: 3.9063e-06
# Epoch 65/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - auc_pr: 0.3122 - auc_roc: 0.7132 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1154
#
# Epoch 65: val_pr_auc did not improve from 0.31293
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 54s 24ms/step - auc_pr: 0.3106 - auc_roc: 0.7126 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1154 - learning_rate: 3.9063e-06
# Epoch 66/300
# 2263/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3123 - auc_roc: 0.7133 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1170
#
# Epoch 66: val_pr_auc did not improve from 0.31293
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 57s 25ms/step - auc_pr: 0.3107 - auc_roc: 0.7128 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1170 - learning_rate: 1.9531e-06
# Epoch 67/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3122 - auc_roc: 0.7131 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1167
#
# Epoch 67: val_pr_auc did not improve from 0.31293
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 56s 25ms/step - auc_pr: 0.3106 - auc_roc: 0.7126 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1167 - learning_rate: 1.9531e-06
# Epoch 68/300
# 2261/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3125 - auc_roc: 0.7130 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1166
#
# Epoch 68: val_pr_auc did not improve from 0.31293
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 56s 25ms/step - auc_pr: 0.3108 - auc_roc: 0.7125 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1166 - learning_rate: 1.9531e-06
# Epoch 69/300
# 2263/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3119 - auc_roc: 0.7131 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1159
#
# Epoch 69: val_pr_auc did not improve from 0.31293
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 56s 25ms/step - auc_pr: 0.3104 - auc_roc: 0.7126 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1159 - learning_rate: 1.9531e-06
# Epoch 70/300
# 2263/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3122 - auc_roc: 0.7132 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1161
#
# Epoch 70: val_pr_auc did not improve from 0.31293
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1e-06.
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 55s 24ms/step - auc_pr: 0.3107 - auc_roc: 0.7127 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1161 - learning_rate: 1.9531e-06
# Epoch 71/300
# 2265/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3121 - auc_roc: 0.7131 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1170
#
# Epoch 71: val_pr_auc did not improve from 0.31293
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 57s 25ms/step - auc_pr: 0.3107 - auc_roc: 0.7126 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1170 - learning_rate: 1.0000e-06
# Epoch 72/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3125 - auc_roc: 0.7130 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1167
#
# Epoch 72: val_pr_auc did not improve from 0.31293
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 57s 25ms/step - auc_pr: 0.3108 - auc_roc: 0.7126 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1167 - learning_rate: 1.0000e-06
# Epoch 73/300
# 2262/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3122 - auc_roc: 0.7133 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1164
#
# Epoch 73: val_pr_auc did not improve from 0.31293
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 56s 25ms/step - auc_pr: 0.3105 - auc_roc: 0.7126 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1164 - learning_rate: 1.0000e-06
# Epoch 74/300
# 2266/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3119 - auc_roc: 0.7132 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1167
#
# Epoch 74: val_pr_auc did not improve from 0.31293
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 56s 25ms/step - auc_pr: 0.3104 - auc_roc: 0.7126 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1167 - learning_rate: 1.0000e-06
# Epoch 75/300
# 2261/2268 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - auc_pr: 0.3122 - auc_roc: 0.7131 - loss: 0.0466  — val_pr_auc=0.3129  val_roc_auc=0.7134  val_f1_sig=0.1172
#
# Epoch 75: val_pr_auc did not improve from 0.31293
# 2268/2268 ━━━━━━━━━━━━━━━━━━━━ 57s 25ms/step - auc_pr: 0.3106 - auc_roc: 0.7126 - loss: 0.0464 - val_auc_pr: 0.3128 - val_auc_roc: 0.7133 - val_loss: 0.0463 - val_pr_auc: 0.3129 - val_roc_auc: 0.7134 - val_f1_sig: 0.1172 - learning_rate: 1.0000e-06
# Epoch 75: early stopping
# Restoring model weights from the end of the best epoch: 60.
# Best val PR-AUC: 0.31293022243263835
# Best val ROC-AUC: 0.7134155449339118

# %% [markdown]
# ## 11. Training curves

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 4))
axes[0].plot(history.history["loss"], label="train")
axes[0].plot(history.history["val_loss"], label="val")
axes[0].set_title("Focal loss"); axes[0].legend(); axes[0].grid(alpha=0.3)

axes[1].plot(history.history["val_pr_auc"],  label="val PR-AUC")
axes[1].plot(history.history["val_roc_auc"], label="val ROC-AUC")
axes[1].set_title("Validation AUCs"); axes[1].legend(); axes[1].grid(alpha=0.3)

axes[2].plot(history.history["val_f1_sig"], label="val F1 (qqbar)")
axes[2].set_title("Validation signal F1"); axes[2].legend(); axes[2].grid(alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "training_curves.png", dpi=150)
plt.show()

# %% [markdown]
# ## 12. Test-set evaluation

# %%
p_test = model.predict(X_test_pp, verbose=0).ravel()

roc = roc_auc_score(y_test, p_test)
pr  = average_precision_score(y_test, p_test)
print(f"Test ROC-AUC: {roc:.4f}")
print(f"Test PR-AUC : {pr:.4f}   (baseline = signal fraction = {y_test.mean():.4f})")
print()
print("Classification report @ threshold 0.5:")
print(classification_report(y_test, (p_test>=0.5).astype(int),
                            target_names=["qg+gg", "qqbar"]))

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
# ROC
fpr, tpr, _ = roc_curve(y_test, p_test)
axes[0].plot(fpr, tpr, label=f"AUC={roc:.3f}")
axes[0].plot([0,1],[0,1],"k--", alpha=0.4)
axes[0].set_xlabel("FPR"); axes[0].set_ylabel("TPR")
axes[0].set_title("ROC — qqbar vs rest"); axes[0].legend(); axes[0].grid(alpha=0.3)
# PR
prec, rec, _ = precision_recall_curve(y_test, p_test)
axes[1].plot(rec, prec, label=f"AP={pr:.3f}")
axes[1].axhline(y_test.mean(), color="k", ls="--", alpha=0.4,
                label=f"baseline={y_test.mean():.3f}")
axes[1].set_xlabel("Recall (qqbar eff)"); axes[1].set_ylabel("Precision (qqbar purity)")
axes[1].set_title("Precision-Recall — qqbar"); axes[1].legend(); axes[1].grid(alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "test_roc_pr.png", dpi=150)
plt.show()
# Out:
# Test ROC-AUC: 0.7143
# Test PR-AUC : 0.3138   (baseline = signal fraction = 0.1294)
#
# Classification report @ threshold 0.5:
#               precision    recall  f1-score   support
#
#        qg+gg       0.88      0.99      0.93   1991697
#        qqbar       0.62      0.06      0.11    295977
#
#     accuracy                           0.87   2287674
#    macro avg       0.75      0.53      0.52   2287674
# weighted avg       0.84      0.87      0.83   2287674

# %% [markdown]
# ## 13. Purity / efficiency vs threshold
#
# This is the key table for selecting a pure qqbar sample.

# %%
rows = []
for thr in np.arange(0.30, 0.96, 0.05):
    sel = p_test >= thr
    if sel.sum() == 0:
        continue
    purity = y_test[sel].mean()                      # fraction of selected that are qqbar
    eff    = (y_test[sel].sum()) / y_test.sum()       # fraction of all qqbar selected
    rows.append({"threshold": round(thr,2),
                 "N_selected": int(sel.sum()),
                 "purity": round(purity,4),
                 "efficiency": round(eff,4)})

purity_df = pd.DataFrame(rows)
print(purity_df.to_string(index=False))
purity_df.to_csv(OUTPUT_DIR / "qqbar_purity_efficiency.csv", index=False)

fig, ax1 = plt.subplots(figsize=(8,5))
ax2 = ax1.twinx()
ax1.plot(purity_df.threshold, purity_df.purity,     "o-", color="#4c72b0", label="purity")
ax2.plot(purity_df.threshold, purity_df.efficiency, "s--", color="#dd8452", label="efficiency")
ax1.axhline(y_test.mean(), color="grey", ls=":", label=f"baseline purity={y_test.mean():.3f}")
ax1.set_xlabel("Threshold"); ax1.set_ylabel("Purity", color="#4c72b0")
ax2.set_ylabel("Efficiency", color="#dd8452")
ax1.set_title("qqbar purity vs efficiency")
l1,lb1 = ax1.get_legend_handles_labels(); l2,lb2 = ax2.get_legend_handles_labels()
ax1.legend(l1+l2, lb1+lb2, loc="center right", fontsize=9)
ax1.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "purity_efficiency.png", dpi=150)
plt.show()
# Out:
#  threshold  N_selected  purity  efficiency
#       0.30     1319798  0.1807      0.8057
#       0.35      534802  0.2697      0.4874
#       0.40      211459  0.3789      0.2707
#       0.45       81911  0.4995      0.1382
#       0.50       30446  0.6160      0.0634
#       0.55       10111  0.7162      0.0245
#       0.60        2455  0.8020      0.0067
#       0.65         319  0.8652      0.0009
#       0.70          16  0.9375      0.0001

# %% [markdown]
# ## 14. Physics validation — cos(Δψ) of the selected qqbar sample

# %%
# g->qqbar should show <cos(dpsi)> < 0  (planes anti-correlated)
# Recover dpsi12 for the test rows
test_dpsi = df.loc[X_test.index, "dpsi12"].to_numpy()

print("thr    purity   eff     N        <cos2psi>    err")
for thr in np.arange(0.30, 0.62, 0.025):
    sel = p_test >= thr
    n = int(sel.sum())
    if n < 50:                      # skip when too few jets to be meaningful
        continue
    cosd = np.cos(2 * test_dpsi[sel])
    pur  = y_test[sel].mean()
    eff  = y_test[sel].sum() / y_test.sum()
    err  = cosd.std() / np.sqrt(n)
    print(f"{thr:.3f}  {pur:.3f}   {eff:.3f}  {n:7d}  {cosd.mean():+.4f}   {err:.4f}")

# Compare with true qqbar and true qg+gg
print()
true_qqbar = np.cos(2 * test_dpsi[y_test==1])
true_rest  = np.cos(2 * test_dpsi[y_test==0])
print(f"TRUE qqbar : <2*cos(dpsi)> = {true_qqbar.mean():+.4f}  (N={(y_test==1).sum():,})")
print(f"TRUE qg+gg : <2*cos(dpsi)> = {true_rest.mean():+.4f}  (N={(y_test==0).sum():,})")

# Plot dpsi distribution for selected vs rest
fig, ax = plt.subplots(figsize=(8,5))
sel85 = p_test >= 0.85
ax.hist(test_dpsi[y_test==1], bins=50, density=True, alpha=0.5,
        label="true qqbar", color="#4c72b0")
ax.hist(test_dpsi[sel85], bins=50, density=True, alpha=0.5,
        label="DNN-selected (thr 0.85)", color="#55a868", histtype="step", lw=2)
ax.set_xlabel("Δψ"); ax.set_ylabel("density")
ax.set_title("Δψ: true qqbar vs DNN-selected sample")
ax.legend(); ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "dpsi_validation.png", dpi=150)
plt.show()
# Out:
# thr    purity   eff     N        <cos2psi>    err
# 0.300  0.181   0.806  1319798  -0.0703   0.0006
# 0.325  0.221   0.638   852527  -0.0793   0.0008
# 0.350  0.270   0.487   534802  -0.0942   0.0010
# 0.375  0.322   0.366   336639  -0.1128   0.0012
# 0.400  0.379   0.271   211459  -0.1321   0.0015
# 0.425  0.439   0.196   132152  -0.1544   0.0019
# 0.450  0.499   0.138    81911  -0.1767   0.0024
# 0.475  0.559   0.095    50166  -0.2019   0.0031
# 0.500  0.616   0.063    30446  -0.2197   0.0039
# 0.525  0.671   0.040    17850  -0.2405   0.0051
# 0.550  0.716   0.024    10111  -0.2644   0.0068
# 0.575  0.760   0.014     5325  -0.2828   0.0092
# 0.600  0.802   0.007     2455  -0.3158   0.0134
#
# TRUE qqbar : <2*cos(dpsi)> = -0.1723  (N=295,977)
# TRUE qg+gg : <2*cos(dpsi)> = -0.0745  (N=1,991,697)
# /opt/anaconda3/envs/pic2-ml/lib/python3.11/site-packages/numpy/lib/histograms.py:885: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
